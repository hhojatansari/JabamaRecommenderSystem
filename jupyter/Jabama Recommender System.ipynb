# %% [markdown]
# ### Import packages

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 100)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import pairwise_distances

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Functions

# %% [markdown]
# ### Load Data

# %%
data = pd.read_pickle('../data/jabama_gilan_products.pickle')
data.head()
# Out:
#           product_id score area capacity room floor stair    price        lat  \
# 0       villa-503599  None   98        7    2     0    15  1000000  37.328673
# 1  ecotourism-597882     3   80        7    1     0     2   660000  37.096812
# 2       villa-361255   4.5   60        3    1     0  None   467000  37.184390
# 3     complex-376108     4   28        3    0     0  None   500000  36.804887
# 4       villa-323476   3.6  120        6    2     0     4  1500000  36.963060
#
#          lng  iranian_toilet  western_toilet  bathroom  exclusive  breakfast
# 0  49.128113            True            True      True      False      False
# 1  49.652710            True            True      True      False      False
# 2  49.169312            True           False      True      False      False
# 3  49.413757            True           False      True      False      False
# 4  49.578552            True           False      True       True      False

# %% [markdown]
# ## Preprocessing

# %%
# fill none stair and score by zero
data.loc[data.score.isna(), 'score'] = 0
data.loc[data.stair.isna(), 'stair'] = 0

# %%
data.isna().sum()
# Out:
# product_id        0
# score             0
# area              0
# capacity          0
# room              0
# floor             0
# stair             0
# price             0
# lat               0
# lng               0
# iranian_toilet    0
# western_toilet    0
# bathroom          0
# exclusive         0
# breakfast         0
# dtype: int64

# %%
data.iranian_toilet = data.iranian_toilet.apply(lambda x: 1 if x else 0)
data.western_toilet = data.western_toilet.apply(lambda x: 1 if x else 0)
data.bathroom = data.bathroom.apply(lambda x: 1 if x else 0)
data.exclusive = data.exclusive.apply(lambda x: 1 if x else 0)
data.breakfast = data.breakfast.apply(lambda x: 1 if x else 0)

# %%
data['type'] = data.product_id.apply(lambda x: x.split('-')[0])

# %% [markdown]
# ## Numerical features

# %%
num_product = data.drop(['product_id', 'lat', 'lng'], axis=1)
num_columns = num_product.columns

# %%
num_product
# Out:
#      score area capacity room floor stair    price  iranian_toilet  \
# 0        0   98        7    2     0    15  1000000               1
# 1        3   80        7    1     0     2   660000               1
# 2      4.5   60        3    1     0     0   467000               1
# 3        4   28        3    0     0     0   500000               1
# 4      3.6  120        6    2     0     4  1500000               1
# ...    ...  ...      ...  ...   ...   ...      ...             ...
# 4698   4.8   40        4    0     0     0   814000               1
# 4699   4.5   70        6    2     0     0  1000000               1
# 4700   4.7  150       15    3     2    20  2000000               1
# 4701   4.7   90        6    1     0     3   553000               1
# 4702   4.9   80       10    0     0     0  1050000               1
#
#       western_toilet  bathroom  exclusive  breakfast        type
# 0                  1         1          0          0       villa
# 1                  1         1          0          0  ecotourism
# 2                  0         1          0          0       villa
# 3                  0         1          0          0     complex
# 4                  0         1          1          0       villa
# ...              ...       ...        ...        ...         ...
# 4698               0         1          0          0     complex
# 4699               1         1          0          0       villa
# 4700               1         1          1          0   apartment
# 4701               0         1          0          0       villa
# 4702               0         1          0          0       villa
#
# [4703 rows x 13 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
enc = OneHotEncoder()

# %%
enc.fit_transform(num_product[['type']])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 4703 stored elements and shape (4703, 9)>

# %%
num_scaler = MinMaxScaler()
scaled_num = num_scaler.fit_transform(num_product)

pd.DataFrame(scaled_num, index=data.product_id, columns=num_columns).head() # just for show result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_11689/114716942.py in ?()
#       1 num_scaler = MinMaxScaler()
# ----> 2 scaled_num = num_scaler.fit_transform(num_product)
#       3
#       4 pd.DataFrame(scaled_num, index=data.product_id, columns=num_columns).head() # just for show result
#
# ~/PycharmProjects/JabamaRecommenderSystem/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# ~/PycharmProjects/JabamaRecommenderSystem/.venv/lib/python3.12/site-packages/sklearn/base.py in ?(self, X, y, **fit_params)
#     914                 )
#     915
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# --> 918             return self.fit(X, **fit_params).transform(X)
#     919         else:
#     920             # fit method of arity 2 (supervised transformation)
#     921             return self.fit(X, y, **fit_params).transform(X)
#
# ~/PycharmProjects/JabamaRecommenderSystem/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y)
#     443             Fitted scaler.
#     444         """
#     445         # Reset internal state before fitting
#     446         self._reset()
# --> 447         return self.partial_fit(X, y)
#
# ~/PycharmProjects/JabamaRecommenderSystem/.venv/lib/python3.12/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# ~/PycharmProjects/JabamaRecommenderSystem/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y)
#     483
#     484         xp, _ = get_namespace(X)
#     485
#     486         first_pass = not hasattr(self, "n_samples_seen_")
# --> 487         X = validate_data(
#     488             self,
#     489             X,
#     490             reset=first_pass,
#
# ~/PycharmProjects/JabamaRecommenderSystem/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2940             out = y
#    2941         else:
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#    2947     else:
#
# ~/PycharmProjects/JabamaRecommenderSystem/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# ~/PycharmProjects/JabamaRecommenderSystem/.venv/lib/python3.12/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# ~/PycharmProjects/JabamaRecommenderSystem/.venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'villa'

# %%
num_weights = {
    "score": 2,
    "area": 1,
    "capacity": 4,
    "room": 3,
    "floor": 2,
    "stair": 1,
    "price": 10,
    "iranian_toilet": 0.5,
    "western_toilet": 1,
    "bathroom": 1,
    "exclusive": 1,
    "breakfast": 1
}
num_weights_df = pd.DataFrame(num_weights, columns=num_columns, index=num_product.index) # convert to df

# %%
num_products_vector = pd.DataFrame(scaled_num, columns=num_columns).mul(num_weights_df)
num_products_vector.describe().T.sort_values('mean', ascending=False)
# Out:
#                  count      mean       std  min       25%       50%       75%  \
# score           4703.0  1.444329  0.686545  0.0  1.400000  1.760000  1.880000
# capacity        4703.0  0.750824  0.400715  0.0  0.500000  0.625000  0.875000
# price           4703.0  0.666129  0.575130  0.0  0.350000  0.500000  0.750000
# western_toilet  4703.0  0.588773  0.492109  0.0  0.000000  1.000000  1.000000
# room            4703.0  0.553769  0.337437  0.0  0.375000  0.750000  0.750000
# iranian_toilet  4703.0  0.448969  0.151381  0.0  0.500000  0.500000  0.500000
# floor           4703.0  0.429159  0.224736  0.0  0.333333  0.333333  0.333333
# exclusive       4703.0  0.305337  0.460599  0.0  0.000000  0.000000  1.000000
# area            4703.0  0.143796  0.086295  0.0  0.092308  0.130769  0.169231
# stair           4703.0  0.066222  0.100763  0.0  0.000000  0.042857  0.071429
# breakfast       4703.0  0.012120  0.109433  0.0  0.000000  0.000000  0.000000
# bathroom        4703.0  0.000000  0.000000  0.0  0.000000  0.000000  0.000000
#
#                  max
# score            2.0
# capacity         4.0
# price           10.0
# western_toilet   1.0
# room             3.0
# iranian_toilet   0.5
# floor            2.0
# exclusive        1.0
# area             1.0
# stair            1.0
# breakfast        1.0
# bathroom         0.0

# %% [markdown]
# ### Calculate rooms distance

# %%
num_distance_matrix = pairwise_distances(num_products_vector.values, metric='euclidean')
pd.DataFrame(num_distance_matrix, index=data.product_id, columns=data.product_id) # just for show result
# Out:
# product_id         villa-503599  ecotourism-597882  villa-361255  \
# product_id
# villa-503599           0.000000           1.282490      2.179675
# ecotourism-597882      1.282490           0.000000      1.273215
# villa-361255           2.179675           1.273215      0.000000
# complex-376108         2.119556           1.250696      0.428160
# villa-323476           2.043909           1.547531      1.299772
# ...                         ...                ...           ...
# complex-370677         2.334963           1.345430      0.449109
# villa-379164           1.817526           0.739055      1.162974
# apartment-491137       2.526058           1.998991      2.439605
# villa-487515           2.184065           1.217098      0.390949
# villa-399760           2.364748           1.377567      1.008845
#
# product_id         complex-376108  villa-323476  complex-380288  villa-501818  \
# product_id
# villa-503599             2.119556      2.043909        2.065832      1.580433
# ecotourism-597882        1.250696      1.547531        1.194774      0.521527
# villa-361255             0.428160      1.299772        0.464114      1.268166
# complex-376108           0.000000      1.414929        0.134037      1.145224
# villa-323476             1.414929      0.000000        1.391183      1.776716
# ...                           ...           ...             ...           ...
# complex-370677           0.378173      1.411192        0.403464      1.281295
# villa-379164             1.345288      1.483672        1.327074      1.041507
# apartment-491137         2.591878      1.777968        2.533112      2.325902
# villa-487515             0.609333      1.249304        0.563182      1.256194
# villa-399760             0.988560      1.463071        0.904043      1.410708
#
# product_id         complex-655221  villa-545746  apartment-508766  ...  \
# product_id                                                         ...
# villa-503599             1.425173      2.277216          1.890498  ...
# ecotourism-597882        1.768358      1.321070          1.233295  ...
# villa-361255             2.025723      0.586616          0.637697  ...
# complex-376108           1.810680      0.780371          0.871661  ...
# villa-323476             2.053794      1.216837          1.147397  ...
# ...                           ...           ...               ...  ...
# complex-370677           2.068934      0.534241          0.933578  ...
# villa-379164             2.308572      1.102621          1.137334  ...
# apartment-491137         2.891906      2.116946          2.156604  ...
# villa-487515             2.053671      0.361716          0.689823  ...
# villa-399760             2.149693      0.647648          1.214772  ...
#
# product_id         inn-389108  villa-402641  villa-639276  cottage-475354  \
# product_id
# villa-503599         2.015340      1.786333      0.196104        2.585176
# ecotourism-597882    0.792763      0.947030      1.277851        2.372509
# villa-361255         1.118775      1.561485      2.204308        2.655845
# complex-376108       1.078583      1.683505      2.146008        2.692694
# villa-323476         1.684800      1.533423      2.049156        1.836541
# ...                       ...           ...           ...             ...
# complex-370677       1.012597      1.576230      2.351983        2.607733
# villa-379164         0.763075      0.685859      1.821022        2.446903
# apartment-491137     2.162268      1.442927      2.486355        1.606295
# villa-487515         1.091452      1.372832      2.189082        2.369447
# villa-399760         1.187932      1.350848      2.340565        2.056545
#
# product_id         cottage-611772  complex-370677  villa-379164  \
# product_id
# villa-503599             1.882600        2.334963      1.817526
# ecotourism-597882        1.229803        1.345430      0.739055
# villa-361255             1.815793        0.449109      1.162974
# complex-376108           1.995500        0.378173      1.345288
# villa-323476             1.668361        1.411192      1.483672
# ...                           ...             ...           ...
# complex-370677           1.892950        0.000000      1.284593
# villa-379164             0.940893        1.284593      0.000000
# apartment-491137         1.302374        2.462563      1.789937
# villa-487515             1.598713        0.479071      1.095336
# villa-399760             1.597740        0.762765      1.356083
#
# product_id         apartment-491137  villa-487515  villa-399760
# product_id
# villa-503599               2.526058      2.184065      2.364748
# ecotourism-597882          1.998991      1.217098      1.377567
# villa-361255               2.439605      0.390949      1.008845
# complex-376108             2.591878      0.609333      0.988560
# villa-323476               1.777968      1.249304      1.463071
# ...                             ...           ...           ...
# complex-370677             2.462563      0.479071      0.762765
# villa-379164               1.789937      1.095336      1.356083
# apartment-491137           0.000000      2.205339      2.103794
# villa-487515               2.205339      0.000000      0.678860
# villa-399760               2.103794      0.678860      0.000000
#
# [4703 rows x 4703 columns]

# %% [markdown]
# ## Geographical features

# %%
geo_product = data[['lat', 'lng']]

# %% [markdown]
# ### Calculate products geo distance

# %%
geo_product_radians = np.radians(geo_product.values)
geo_distance_matrix = pairwise_distances(geo_product_radians, metric='haversine')
geo_distance_matrix_km = geo_distance_matrix * 6371

# %%
s_min = 0
s_max = 1
geo_distance_matrix = (geo_distance_matrix - geo_distance_matrix.min()) / (geo_distance_matrix.max() - geo_distance_matrix.min())
geo_distance_matrix = geo_distance_matrix * (s_max - s_min) + s_min
pd.DataFrame(geo_distance_matrix, index=data.product_id, columns=data.product_id) # just for show result
# Out:
# product_id         villa-503599  ecotourism-597882  villa-361255  \
# product_id
# villa-503599           0.000000           0.223483      0.069205
# ecotourism-597882      0.223483           0.000000      0.184829
# villa-361255           0.069205           0.184829      0.000000
# complex-376108         0.267175           0.163157      0.199613
# villa-323476           0.239674           0.068413      0.184498
# ...                         ...                ...           ...
# complex-370677         0.146992           0.182691      0.175783
# villa-379164           0.546289           0.330759      0.515358
# apartment-491137       0.114834           0.143570      0.050704
# villa-487515           0.057458           0.264861      0.126662
# villa-399760           0.146543           0.105793      0.088919
#
# product_id         complex-376108  villa-323476  complex-380288  villa-501818  \
# product_id
# villa-503599             0.267175      0.239674        0.085923      0.286804
# ecotourism-597882        0.163157      0.068413        0.137810      0.179441
# villa-361255             0.199613      0.184498        0.061193      0.291545
# complex-376108           0.000000      0.096302        0.201846      0.342391
# villa-323476             0.096302      0.000000        0.157186      0.247636
# ...                           ...           ...             ...           ...
# complex-370677           0.309410      0.236849        0.124785      0.150701
# villa-379164             0.423942      0.354162        0.463956      0.318129
# apartment-491137         0.152708      0.134714        0.059908      0.275610
# villa-487515             0.323715      0.289864        0.132733      0.294888
# villa-399760             0.130405      0.095623        0.071764      0.253198
#
# product_id         complex-655221  villa-545746  apartment-508766  ...  \
# product_id                                                         ...
# villa-503599             0.129414      0.034690          0.183104  ...
# ecotourism-597882        0.204763      0.190237          0.100008  ...
# villa-361255             0.168896      0.062101          0.177550  ...
# complex-376108           0.320497      0.247746          0.248011  ...
# villa-323476             0.254288      0.210979          0.162537  ...
# ...                           ...           ...               ...  ...
# complex-370677           0.030122      0.122096          0.088054  ...
# villa-379164             0.479277      0.511665          0.371618  ...
# apartment-491137         0.185579      0.095910          0.160682  ...
# villa-487515             0.118842      0.079032          0.205631  ...
# villa-399760             0.191743      0.121294          0.141413  ...
#
# product_id         inn-389108  villa-402641  villa-639276  cottage-475354  \
# product_id
# villa-503599         0.121854      0.182083      0.388930        0.142767
# ecotourism-597882    0.146563      0.100139      0.235762        0.160256
# villa-361255         0.055510      0.176584      0.384732        0.162853
# complex-376108       0.145322      0.247695      0.392058        0.287470
# villa-323476         0.133011      0.162444      0.296497        0.214054
# ...                       ...           ...           ...             ...
# complex-370677       0.193854      0.087478      0.257679        0.022808
# villa-379164         0.475632      0.372549      0.231673        0.434893
# apartment-491137     0.009720      0.159849      0.360263        0.166399
# villa-487515         0.178526      0.204663      0.401048        0.149717
# villa-399760         0.041196      0.140742      0.330766        0.163374
#
# product_id         cottage-611772  complex-370677  villa-379164  \
# product_id
# villa-503599             0.169810        0.146992      0.546289
# ecotourism-597882        0.176833        0.182691      0.330759
# villa-361255             0.193722        0.175783      0.515358
# complex-376108           0.313492        0.309410      0.423942
# villa-323476             0.235523        0.236849      0.354162
# ...                           ...             ...           ...
# complex-370677           0.024493        0.000000      0.449313
# villa-379164             0.428846        0.449313      0.000000
# apartment-491137         0.197068        0.184213      0.473623
# villa-487515             0.169475        0.144982      0.576610
# villa-399760             0.192149        0.183975      0.434436
#
# product_id         apartment-491137  villa-487515  villa-399760
# product_id
# villa-503599               0.114834      0.057458      0.146543
# ecotourism-597882          0.143570      0.264861      0.105793
# villa-361255               0.050704      0.126662      0.088919
# complex-376108             0.152708      0.323715      0.130405
# villa-323476               0.134714      0.289864      0.095623
# ...                             ...           ...           ...
# complex-370677             0.184213      0.144982      0.183975
# villa-379164               0.473623      0.576610      0.434436
# apartment-491137           0.000000      0.171023      0.040184
# villa-487515               0.171023      0.000000      0.199882
# villa-399760               0.040184      0.199882      0.000000
#
# [4703 rows x 4703 columns]

# %% [markdown]
# ## Total rooms distance

# %%
geo_weight = 100

total_rooms_distance = 1 * num_distance_matrix + geo_weight * geo_distance_matrix
result_df = pd.DataFrame(total_rooms_distance, index=data.product_id, columns=data.product_id)

# %%
product_id = 'suite-518283'

for i in result_df.loc[product_id].iloc[:].sort_values().head(10).index:
    print(f'https://www.jabama.com/stay/{i}')
# Out:
# https://www.jabama.com/stay/suite-518283
# https://www.jabama.com/stay/apartment-104932
# https://www.jabama.com/stay/apartment-103834
# https://www.jabama.com/stay/apartment-353414
# https://www.jabama.com/stay/suite-327771
# https://www.jabama.com/stay/villa-108434
# https://www.jabama.com/stay/villa-527782
# https://www.jabama.com/stay/villa-656682
# https://www.jabama.com/stay/apartment-361071
# https://www.jabama.com/stay/apartment-602107
